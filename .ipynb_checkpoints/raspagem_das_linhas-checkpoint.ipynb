# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# buscando elementos de texto da página da ETUFOR
navegador = webdriver.Chrome()
navegador.get("https://moovitapp.com/index/pt-br/transporte_p%C3%BAblico-lines-Fortaleza-983-9809")

linhas = []

for linha in navegador.find_elements(By.CLASS_NAME,'line-title-wrapper'):
    linha = linha.text
    linhas.append(linha)
    print(linha)
# Out:
# 004 Messejana / Papicu / Cambeba / TJ
# 011 Circular I
# 012 Circular II
# 014 Aguanambi / Rodoviária II
# 015 Conjunto Ceará / Antônio Bezerra I
# 016 Cuca Barra / Papicu
# 020 Campus do Pici
# 021 Luciano Cavalcante / Papicu
# 022 Jardim das Oliveiras / Centro
# 024 Antônio Bezerra / Lagoa / Unifor
# 025 Opaia / Lagoa
# 026 Antônio Bezerra / Messejana
# 027 Siqueira / Papicu / Aeroporto
# 028 Antônio Bezerra / Papicu
# 029 Parangaba / Náutico
# 030 Siqueira / Papicu / 13 de Maio
# 031 Av. Borges de Melo / Papicu I
# 032 Av. Borges de Melo / Papicu II
# 034 Corujão / Av. Paranjana I
# 035 Corujão / Av. Paranjana II
# 036 Corujão / Conjunto Ceará / Papicu / Montese
# 038 Parangaba / Papicu
# 040 Parangaba / Lagoa
# 041 Parangaba / Oliveira Paiva / Papicu
# 042 Antônio Bezerra / Francisco Sá / Papicu
# 043 Conjunto Ceará / Lagoa / Fernandes Távora
# 044 Parangaba / Papicu / Montese
# 045 Conjunto Ceará / Papicu / Montese
# 048 Corujão / Parangaba / Papicu
# ...

# %%
# separando em duas listas 
num_linhas = []
nome_linhas = []

for linha in linhas:
    num_linhas.append(linha[:3])
    nome_linhas.append(linhas[5:])

# %%
import pandas as pd
# criando e tratado dados da tabela 
tabela = pd.read_excel("linhas_onibus.xlsx")

display(tabela)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
